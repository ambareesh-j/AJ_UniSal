# %% [markdown]
# # Lab 1 - Big Data Tools & Techniques

# %% [markdown]
# Topic 1 - Explore a directory
# You are currently in /databricks/drivers. To see the files in this directory:

# %%
# %sh
ls
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">conf
# derby.log
# eventlogs
# ganglia
# logs
# </div>

# %% [markdown]
# Topic 2 - What does ls -l in the same place tell you? (You can use Google \ls command Linux" to give you information about
# the command.)

# %%
# %sh
ls -l
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">total 20
# drwxr-xr-x 2 root root 4096 Jan  1  1970 conf
# -rw-r--r-- 1 root root  733 Feb  4 16:48 derby.log
# drwxr-xr-x 3 root root 4096 Feb  4 16:47 eventlogs
# drwxr-xr-x 2 root root 4096 Feb  4 17:00 ganglia
# drwxr-xr-x 2 root root 4096 Feb  4 17:02 logs
# </div>

# %% [markdown]
# Topic 3 - The logs directory looks interesting, look at what's in there using: ls logs

# %%
# %sh

ls -l logs
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">total 1872
# -rw-r--r-- 1 root root    3769 Feb  4 17:00 2021-02-04-16.log.gz
# -rw-r--r-- 1 root root  123209 Feb  4 17:01 2021-02-04-16.metrics.json.gz
# -rw-r--r-- 1 root root   12283 Feb  4 17:00 2021-02-04-16.usage.json.gz
# -rw-r--r-- 1 root root  136842 Feb  4 17:12 active.log
# -rw-r--r-- 1 root root   18543 Feb  4 17:02 log4j-2021-02-04-16.log.gz
# -rw-r--r-- 1 root root   31980 Feb  4 17:12 log4j-active.log
# -rw-r--r-- 1 root root  167200 Feb  4 17:11 metrics.json
# -rw-r--r-- 1 root root     202 Feb  4 17:09 stderr
# -rw-r--r-- 1 root root    2183 Feb  4 16:49 stderr--2021-02-04--17-00
# ...

# %% [markdown]
# Topic 4 - What command would you use to view the contents of the logs/usage.json file?

# %%
cat logs/usage.json
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# ...
