# %% [markdown]
# https://www.youtube.com/watch?v=TNX_GShSyHc&ab_channel=AIEngineering

# %%
dbutils.fs.unmount("/mnt/s3data")

# %%
import urllib

ACCESS_KEY = "XXXXXXXXX"
SECRET_KEY = "XXXXXXXXX"

ENCODED_SECRET_KEY = urllib.parse.quote(SECRET_KEY, "")
AWS_BUCKET_NAME = "ambybucket"
MOUNT_NAME = "s3data"

dbutils.fs.mount("s3n://%s:%s@%s" %(ACCESS_KEY, ENCODED_SECRET_KEY, AWS_BUCKET_NAME), "/mnt/%s" % MOUNT_NAME)

# %%
display(dbutils.fs.ls("/mnt/s3data"))

# %%
display(dbutils.fs.ls("file:/mnt/"))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th></tr></thead><tbody><tr><td>file:/mnt/readonly/</td><td>readonly/</td><td>4096</td></tr><tr><td>file:/mnt/driver-daemon/</td><td>driver-daemon/</td><td>4096</td></tr></tbody></table></div>
