# %% [markdown]
# # Lab: Data storage and Python

# %% [markdown]
# In this lab, you will explore the various data storage options available and do some (sequential) le manipulations using
# Python. You should carry out the following in a Databricks notebook.

# %%
dbutils.fs.help()
# Out:
# <div class = "ansiout"><b>dbutils.fs</b> provides utilities for working with FileSystems. Most methods in
# this package can take either a DBFS path (e.g., "/foo" or "dbfs:/foo"), or
# another FileSystem URI.
#
# For more info about a method, use <b>dbutils.fs.help("methodName")</b>.
#
# In notebooks, you can also use the %fs shorthand to access DBFS. The %fs shorthand maps
# straightforwardly onto dbutils calls. For example, "%fs head --maxBytes=10000 /file/path"
# translates into "dbutils.fs.head("/file/path", maxBytes = 10000)".
#     <h3>fsutils</h3><b>cp(from: String, to: String, recurse: boolean = false): boolean</b> -> Copies a file or directory, possibly across FileSystems<br /><b>head(file: String, maxBytes: int = 65536): String</b> -> Returns up to the first 'maxBytes' bytes of the given file as a String encoded in UTF-8<br /><b>ls(dir: String): Seq</b> -> Lists the contents of a directory<br /><b>mkdirs(dir: String): boolean</b> -> Creates the given directory if it does not exist, also creating any necessary parent directories<br /><b>mv(from: String, to: String, recurse: boolean = false): boolean</b> -> Moves a file or directory, possibly across FileSystems<br /><b>put(file: String, contents: String, overwrite: boolean = false): boolean</b> -> Writes the given String out to a file, encoded in UTF-8<br /><b>rm(dir: String, recurse: boolean = false): boolean</b> -> Removes a file or directory<br /><br /><h3>mount</h3><b>mount(source: String, mountPoint: String, encryptionType: String = "", owner: String = null, extraConfigs: Map = Map.empty[String, String]): boolean</b> -> Mounts the given source directory into DBFS at the given mount point<br /><b>mounts: Seq</b> -> Displays information about what is mounted within DBFS<br /><b>refreshMounts: boolean</b> -> Forces all machines in this cluster to refresh their mount cache, ensuring they receive the most recent information<br /><b>unmount(mountPoint: String): boolean</b> -> Deletes a DBFS mount point<br /><br /></div>

# %% [markdown]
# ## Use a shell script to explore some files

# %% [markdown]
# --> 1. Using a shell command, view the first 2 lines of the local file /databricks/driver/logs/usage.json

# %%
# %sh 

head -2 /databricks/driver/logs/usage.json
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">{&#34;metric&#34;:&#34;serviceUptime&#34;,&#34;tags&#34;:{&#34;driverPublicDns&#34;:&#34;ec2-54-200-33-194.us-west-2.compute.amazonaws.com&#34;,&#34;clusterEbsVolumeType&#34;:&#34;GENERAL_PURPOSE_SSD&#34;,&#34;instanceWorkerEnvId&#34;:&#34;default-worker-env&#34;,&#34;instanceBootstrapType&#34;:&#34;ssh&#34;,&#34;opType&#34;:&#34;TimerTask&#34;,&#34;containerZoneId&#34;:&#34;us-west-2c&#34;,&#34;clusterScalingType&#34;:&#34;fixed_size&#34;,&#34;clusterPinned&#34;:&#34;false&#34;,&#34;clusterNodeType&#34;:&#34;dev-tier-node&#34;,&#34;clusterSku&#34;:&#34;STANDARD_SKU&#34;,&#34;driverContainerId&#34;:&#34;935571070b2e44a2b6a778ea015199f2&#34;,&#34;ngrokNpipEnabled&#34;:&#34;false&#34;,&#34;clusterFirstOnDemand&#34;:&#34;0&#34;,&#34;clusterState&#34;:&#34;Pending&#34;,&#34;enableCredentialPassthrough&#34;:&#34;false&#34;,&#34;clusterLogDeliveryEnabled&#34;:&#34;false&#34;,&#34;clusterLogDestination&#34;:&#34;&#34;,&#34;isSingleUserCluster&#34;:&#34;false&#34;,&#34;driverNodeType&#34;:&#34;dev-tier-node&#34;,&#34;driverInstancePrivateIp&#34;:&#34;10.172.225.28&#34;,&#34;isIMv2Enabled&#34;:&#34;false&#34;,&#34;clusterTargetWorkers&#34;:&#34;0&#34;,&#34;numPerGlobalInitScriptsV2&#34;:&#34;0&#34;,&#34;databricksCommit&#34;:&#34;4ff930792a9bc9a222b7ff7dfb98341e704d047b&#34;,&#34;numPerClusterInitScriptsV2&#34;:&#34;0&#34;,&#34;enableJobsAutostart&#34;:&#34;true&#34;,&#34;clusterStateMessage&#34;:&#34;Starting Spark&#34;,&#34;apacheCommit&#34;:&#34;c9b62711fdec24160c4bdeff8fc09eedb0b75ee0&#34;,&#34;projectName&#34;:&#34;driver&#34;,&#34;region&#34;:&#34;us-west-2&#34;,&#34;userProvidedRemoteVolumeSizeGb&#34;:&#34;0&#34;,&#34;userProvidedRemoteVolumeCount&#34;:&#34;0&#34;,&#34;hostName&#34;:&#34;0212-091341-clan990-10-172-246-56&#34;,&#34;clusterEbsVolumeSize&#34;:&#34;0&#34;,&#34;enableJdbcAutoStart&#34;:&#34;true&#34;,&#34;driverInstanceId&#34;:&#34;i-00e89bf779718895a&#34;,&#34;clusterGeneration&#34;:&#34;0&#34;,&#34;autoTerminationMinutes&#34;:&#34;120&#34;,&#34;clusterId&#34;:&#34;0212-091341-clan990&#34;,&#34;clusterAvailability&#34;:&#34;ON_DEMAND&#34;,&#34;parentOpId&#34;:&#34;Thread-11&#34;,&#34;sparkVersion&#34;:&#34;7.5.x-scala2.12&#34;,&#34;hailEnabled&#34;:&#34;false&#34;,&#34;clusterOwnerOrgId&#34;:&#34;4188761774711191&#34;,&#34;workerEnvironmentId&#34;:&#34;default-worker-env&#34;,&#34;tier&#34;:&#34;tier-0&#34;,&#34;enableDfAcls&#34;:&#34;false&#34;,&#34;rootOpId&#34;:&#34;TimerTask-78a0b28696f27c88&#34;,&#34;clusterNoDriverDaemon&#34;:&#34;false&#34;,&#34;cloudProvider&#34;:&#34;AWS&#34;,&#34;clusterName&#34;:&#34;BDTT LabWork&#34;,&#34;clusterPythonVersion&#34;:&#34;3&#34;,&#34;clusterOwnerUserId&#34;:&#34;1878096729107785&#34;,&#34;privateLinkEnabled&#34;:&#34;false&#34;,&#34;clusterEbsVolumeCount&#34;:&#34;0&#34;,&#34;clusterCreator&#34;:&#34;Webapp&#34;,&#34;clusterAllTags&#34;:&#34;[{\&#34;key\&#34;:\&#34;Name\&#34;,\&#34;value\&#34;:\&#34;ce-worker\&#34;}]&#34;,&#34;enableLocalDiskEncryption&#34;:&#34;false&#34;,&#34;clusterSpotBidPricePercent&#34;:&#34;100&#34;,&#34;clusterResourceClass&#34;:&#34;default&#34;,&#34;enableSqlAclsOnly&#34;:&#34;false&#34;,&#34;buildHash&#34;:&#34;6ff40373028aaf75a88df9ee42bea90cb16e98d3&#34;,&#34;containerType&#34;:&#34;LXC&#34;,&#34;clusterNumSshKeys&#34;:&#34;0&#34;,&#34;opId&#34;:&#34;TimerTask-78a0b28696f27c88&#34;,&#34;branchName&#34;:&#34;branch-3.38-3776-d91a3e15&#34;,&#34;userProvidedRemoteVolumeType&#34;:&#34;ebs_volume_type: GENERAL_PURPOSE_SSD\n&#34;,&#34;opTarget&#34;:&#34;UptimeLogger:driver&#34;,&#34;driverContainerPrivateIp&#34;:&#34;10.172.246.56&#34;,&#34;enableElasticDisk&#34;:&#34;false&#34;,&#34;clusterMetastoreAccessType&#34;:&#34;RDS_DIRECT&#34;,&#34;dataPlaneRegion&#34;:&#34;us-west-2&#34;,&#34;instanceWorkerEnvNetworkType&#34;:&#34;default&#34;,&#34;clusterWorkers&#34;:&#34;0&#34;},&#34;timestamp&#34;:1613124005852,&#34;v&#34;:3,&#34;quantity&#34;:30000.0,&#34;blob&#34;:null}
# {&#34;metric&#34;:&#34;sparkNumPendingTasks&#34;,&#34;tags&#34;:{&#34;driverPublicDns&#34;:&#34;ec2-54-200-33-194.us-west-2.compute.amazonaws.com&#34;,&#34;clusterEbsVolumeType&#34;:&#34;GENERAL_PURPOSE_SSD&#34;,&#34;instanceWorkerEnvId&#34;:&#34;default-worker-env&#34;,&#34;instanceBootstrapType&#34;:&#34;ssh&#34;,&#34;opType&#34;:&#34;ServiceMain&#34;,&#34;containerZoneId&#34;:&#34;us-west-2c&#34;,&#34;clusterScalingType&#34;:&#34;fixed_size&#34;,&#34;clusterPinned&#34;:&#34;false&#34;,&#34;clusterNodeType&#34;:&#34;dev-tier-node&#34;,&#34;clusterSku&#34;:&#34;STANDARD_SKU&#34;,&#34;driverContainerId&#34;:&#34;935571070b2e44a2b6a778ea015199f2&#34;,&#34;ngrokNpipEnabled&#34;:&#34;false&#34;,&#34;clusterFirstOnDemand&#34;:&#34;0&#34;,&#34;clusterState&#34;:&#34;Pending&#34;,&#34;enableCredentialPassthrough&#34;:&#34;false&#34;,&#34;clusterLogDeliveryEnabled&#34;:&#34;false&#34;,&#34;clusterLogDestination&#34;:&#34;&#34;,&#34;isSingleUserCluster&#34;:&#34;false&#34;,&#34;driverNodeType&#34;:&#34;dev-tier-node&#34;,&#34;driverInstancePrivateIp&#34;:&#34;10.172.225.28&#34;,&#34;isIMv2Enabled&#34;:&#34;false&#34;,&#34;clusterTargetWorkers&#34;:&#34;0&#34;,&#34;numPerGlobalInitScriptsV2&#34;:&#34;0&#34;,&#34;databricksCommit&#34;:&#34;4ff930792a9bc9a222b7ff7dfb98341e704d047b&#34;,&#34;numPerClusterInitScriptsV2&#34;:&#34;0&#34;,&#34;enableJobsAutostart&#34;:&#34;true&#34;,&#34;clusterStateMessage&#34;:&#34;Starting Spark&#34;,&#34;apacheCommit&#34;:&#34;c9b62711fdec24160c4bdeff8fc09eedb0b75ee0&#34;,&#34;projectName&#34;:&#34;driver&#34;,&#34;region&#34;:&#34;us-west-2&#34;,&#34;userProvidedRemoteVolumeSizeGb&#34;:&#34;0&#34;,&#34;userProvidedRemoteVolumeCount&#34;:&#34;0&#34;,&#34;hostName&#34;:&#34;0212-091341-clan990-10-172-246-56&#34;,&#34;clusterEbsVolumeSize&#34;:&#34;0&#34;,&#34;enableJdbcAutoStart&#34;:&#34;true&#34;,&#34;driverInstanceId&#34;:&#34;i-00e89bf779718895a&#34;,&#34;clusterGeneration&#34;:&#34;0&#34;,&#34;autoTerminationMinutes&#34;:&#34;120&#34;,&#34;clusterId&#34;:&#34;0212-091341-clan990&#34;,&#34;clusterAvailability&#34;:&#34;ON_DEMAND&#34;,&#34;samplingIntervalMillis&#34;:&#34;15000&#34;,&#34;parentOpId&#34;:&#34;Thread-1&#34;,&#34;sparkVersion&#34;:&#34;7.5.x-scala2.12&#34;,&#34;hailEnabled&#34;:&#34;false&#34;,&#34;clusterOwnerOrgId&#34;:&#34;4188761774711191&#34;,&#34;workerEnvironmentId&#34;:&#34;default-worker-env&#34;,&#34;tier&#34;:&#34;tier-0&#34;,&#34;enableDfAcls&#34;:&#34;false&#34;,&#34;rootOpId&#34;:&#34;ServiceMain-78a0b28696f20002&#34;,&#34;clusterNoDriverDaemon&#34;:&#34;false&#34;,&#34;cloudProvider&#34;:&#34;AWS&#34;,&#34;clusterName&#34;:&#34;BDTT LabWork&#34;,&#34;clusterPythonVersion&#34;:&#34;3&#34;,&#34;clusterOwnerUserId&#34;:&#34;1878096729107785&#34;,&#34;privateLinkEnabled&#34;:&#34;false&#34;,&#34;clusterEbsVolumeCount&#34;:&#34;0&#34;,&#34;clusterCreator&#34;:&#34;Webapp&#34;,&#34;clusterAllTags&#34;:&#34;[{\&#34;key\&#34;:\&#34;Name\&#34;,\&#34;value\&#34;:\&#34;ce-worker\&#34;}]&#34;,&#34;enableLocalDiskEncryption&#34;:&#34;false&#34;,&#34;clusterSpotBidPricePercent&#34;:&#34;100&#34;,&#34;clusterResourceClass&#34;:&#34;default&#34;,&#34;enableSqlAclsOnly&#34;:&#34;false&#34;,&#34;buildHash&#34;:&#34;6ff40373028aaf75a88df9ee42bea90cb16e98d3&#34;,&#34;containerType&#34;:&#34;LXC&#34;,&#34;clusterNumSshKeys&#34;:&#34;0&#34;,&#34;opId&#34;:&#34;ServiceMain-78a0b28696f20002&#34;,&#34;branchName&#34;:&#34;branch-3.38-3776-d91a3e15&#34;,&#34;userProvidedRemoteVolumeType&#34;:&#34;ebs_volume_type: GENERAL_PURPOSE_SSD\n&#34;,&#34;opTarget&#34;:&#34;serviceSpecificMain&#34;,&#34;driverContainerPrivateIp&#34;:&#34;10.172.246.56&#34;,&#34;enableElasticDisk&#34;:&#34;false&#34;,&#34;clusterMetastoreAccessType&#34;:&#34;RDS_DIRECT&#34;,&#34;sparkAppl

# %% [markdown]
# --> 2. Use the dbsutil.fs utility to view the first 961 bytes of the DBFS file /databricks-datasets/sample logs/part-00000.

# %%
#%fs head("/databricks-datasets/sample_logs/part-00000")    #    ---> Test - gives 65536 bytes max by default
#dbutils.fs.head("dbfs:/databricks-datasets/sample_logs/part-00000", "maxBytes: int(100)")     # --> doesn't work
dbutils.fs.head("dbfs:/databricks-datasets/sample_logs/part-00000",961)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">[Truncated to first 961 bytes]
# Out[9]: &#39;3.3.3.3 - user1 [21/Jun/2014:10:00:00 -0700] &#34;GET /endpoint_27 HTTP/1.1&#34; 200 21\n4.4.4.4 - user2 [21/Feb/2014:10:00:00 -0300] &#34;GET /endpoint_988 HTTP/1.1&#34; 200 435\n3.3.3.3 - user2 [21/Jan/2014:10:00:00 -0200] &#34;GET /endpoint_271 HTTP/1.1&#34; 200 11\n4.4.4.4 - user1 [21/Mar/2014:10:00:00 -0400] &#34;POST /endpoint_906 HTTP/1.1&#34; 401 182\n3.3.3.3 - - [21/May/2014:10:00:00 -0600] &#34;GET /endpoint_381 HTTP/1.1&#34; 500 208\n2.2.2.2 - - [21/May/2014:10:00:00 -0600] &#34;GET /endpoint_99 HTTP/1.1&#34; 500 201\n3.3.3.3 - user1 [21/Jul/2014:10:00:00 -0800] &#34;GET /endpoint_185 HTTP/1.1&#34; 200 377\n4.4.4.4 - - [21/Mar/2014:10:00:00 -0400] &#34;PUT /endpoint_339 HTTP/1.1&#34; 200 428\n3.3.3.3 - - [21/Apr/2014:10:00:00 -0500] &#34;PUT /endpoint_711 HTTP/1.1&#34; 200 316\n2.2.2.2 - - [21/Apr/2014:10:00:00 -0500] &#34;POST /endpoint_791 HTTP/1.1&#34; 200 374\n127.0.0.1 - - [21/Jul/2014:10:00:00 -0800] &#34;GET /endpoint_137 HTTP/1.1&#34; 500 159\n4.4.4.4 - user1 [21/Jan/2014:10:00:00 -0200] &#34;POST /endpoint_718 HTTP/1.1&#34; 200 291\n&#39;</div>

# %% [markdown]
# --> 3. In your browser, you can explore the details of the S3 settings of a publicly available bucket hosted at
# https://landsat-pds.s3.amazonaws.com.

# %% [markdown]
# --> 4. Now we'll put a file from this dataset (from S3) in your DBFS on Databricks. You should copy the following file to
# DBFS /FileStore/landsat data.txt using dbutils.fs.cp from the the path
# s3a://landsat-pds/L8/139/045/LC81390452014295LGN00/LC81390452014295LGN00 MTL.txt

# %%
dbutils.fs.cp("s3a://landsat-pds/L8/139/045/LC81390452014295LGN00/LC81390452014295LGN00_MTL.txt", "dbfs:/FileStore/landsat_data.txt")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[10]: True</div>

# %% [markdown]
# --> 5. View the first 2997 bytes of your newly downloaded file.

# %%
dbutils.fs.head("dbfs:/FileStore/landsat_data.txt", 2997)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">[Truncated to first 2997 bytes]
# Out[11]: &#39;GROUP = L1_METADATA_FILE\n  GROUP = METADATA_FILE_INFO\n    ORIGIN = &#34;Image courtesy of the U.S. Geological Survey&#34;\n    REQUEST_ID = &#34;0501410225527_00035&#34;\n    LANDSAT_SCENE_ID = &#34;LC81390452014295LGN00&#34;\n    FILE_DATE = 2014-10-22T08:42:59Z\n    STATION_ID = &#34;LGN&#34;\n    PROCESSING_SOFTWARE_VERSION = &#34;LPGS_2.4.0&#34;\n  END_GROUP = METADATA_FILE_INFO\n  GROUP = PRODUCT_METADATA\n    DATA_TYPE = &#34;L1T&#34;\n    ELEVATION_SOURCE = &#34;GLS2000&#34;\n    OUTPUT_FORMAT = &#34;GEOTIFF&#34;\n    SPACECRAFT_ID = &#34;LANDSAT_8&#34;\n    SENSOR_ID = &#34;OLI_TIRS&#34;\n    WRS_PATH = 139\n    WRS_ROW = 45\n    NADIR_OFFNADIR = &#34;NADIR&#34;\n    TARGET_WRS_PATH = 139\n    TARGET_WRS_ROW = 45\n    DATE_ACQUIRED = 2014-10-22\n    SCENE_CENTER_TIME = 04:37:48.7052949Z\n    CORNER_UL_LAT_PRODUCT = 22.71835\n    CORNER_UL_LON_PRODUCT = 85.85002\n    CORNER_UR_LAT_PRODUCT = 22.71887\n    CORNER_UR_LON_PRODUCT = 88.07598\n    CORNER_LL_LAT_PRODUCT = 20.60731\n    CORNER_LL_LON_PRODUCT = 85.86664\n    CORNER_LR_LAT_PRODUCT = 20.60778\n    CORNER_LR_LON_PRODUCT = 88.06044\n    CORNER_UL_PROJECTION_X_PRODUCT = 381900.000\n    CORNER_UL_PROJECTION_Y_PRODUCT = 2512800.000\n    CORNER_UR_PROJECTION_X_PRODUCT = 610500.000\n    CORNER_UR_PROJECTION_Y_PRODUCT = 2512800.000\n    CORNER_LL_PROJECTION_X_PRODUCT = 381900.000\n    CORNER_LL_PROJECTION_Y_PRODUCT = 2279100.000\n    CORNER_LR_PROJECTION_X_PRODUCT = 610500.000\n    CORNER_LR_PROJECTION_Y_PRODUCT = 2279100.000\n    PANCHROMATIC_LINES = 15581\n    PANCHROMATIC_SAMPLES = 15241\n    REFLECTIVE_LINES = 7791\n    REFLECTIVE_SAMPLES = 7621\n    THERMAL_LINES = 7791\n    THERMAL_SAMPLES = 7621\n    FILE_NAME_BAND_1 = &#34;LC81390452014295LGN00_B1.TIF&#34;\n    FILE_NAME_BAND_2 = &#34;LC81390452014295LGN00_B2.TIF&#34;\n    FILE_NAME_BAND_3 = &#34;LC81390452014295LGN00_B3.TIF&#34;\n    FILE_NAME_BAND_4 = &#34;LC81390452014295LGN00_B4.TIF&#34;\n    FILE_NAME_BAND_5 = &#34;LC81390452014295LGN00_B5.TIF&#34;\n    FILE_NAME_BAND_6 = &#34;LC81390452014295LGN00_B6.TIF&#34;\n    FILE_NAME_BAND_7 = &#34;LC81390452014295LGN00_B7.TIF&#34;\n    FILE_NAME_BAND_8 = &#34;LC81390452014295LGN00_B8.TIF&#34;\n    FILE_NAME_BAND_9 = &#34;LC81390452014295LGN00_B9.TIF&#34;\n    FILE_NAME_BAND_10 = &#34;LC81390452014295LGN00_B10.TIF&#34;\n    FILE_NAME_BAND_11 = &#34;LC81390452014295LGN00_B11.TIF&#34;\n    FILE_NAME_BAND_QUALITY = &#34;LC81390452014295LGN00_BQA.TIF&#34;\n    METADATA_FILE_NAME = &#34;LC81390452014295LGN00_MTL.txt&#34;\n    BPF_NAME_OLI = &#34;LO8BPF20141022042317_20141022060146.01&#34;\n    BPF_NAME_TIRS = &#34;LT8BPF20141022041924_20141022055753.01&#34;\n    CPF_NAME = &#34;L8CPF20141001_20141231.01&#34;\n    RLUT_FILE_NAME = &#34;L8RLUT20130211_20431231v09.h5&#34;\n  END_GROUP = PRODUCT_METADATA\n  GROUP = IMAGE_ATTRIBUTES\n    CLOUD_COVER = 0.38\n    IMAGE_QUALITY_OLI = 9\n    IMAGE_QUALITY_TIRS = 9\n    ROLL_ANGLE = -0.001\n    SUN_AZIMUTH = 147.35570767\n    SUN_ELEVATION = 52.12893938\n    EARTH_SUN_DISTANCE = 0.9953272\n    GROUND_CONTROL_POINTS_VERSION = 2\n    GROUND_CONTROL_POINTS_MODEL = 328\n    GEOMETRIC_RMSE_MODEL = 6.255\n    GEOMETRIC_RMSE_MODEL_Y = 4.177\n    GEOMETRIC_RMSE_MODEL_X = 4.655\n    GROUND_CONTROL_POINTS_VERIFY = 72\n    GEOMETRIC_RMSE_VERIFY = 3.242\n&#39;</div>

# %% [markdown]
# ## Count number of lines using Python

# %% [markdown]
# For small datasets, and a simple processing task, we can read and process a file locally line by line.

# %% [markdown]
# -> 6. The following code opens the local logs/usage.json file and reads it line by line. Since the file path is a string, it
# must be enclosed in quotes.
#
# fp = open ("/ databricks / driver / logs / usage . json ", "r")
# for line in fp:
# print ( line )
# fp. close ()
#
# This opens your file for reading ("r") and creates a file pointer (fp) that you can use to access the file's contents. It
# uses a for loop to go through all the lines in the file and when finished, it closes the file.

# %%
fp = open ("/databricks/driver/logs/usage.json", "r")
for line in fp:
  print ( line )
fp. close ()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">{&#34;metric&#34;:&#34;serviceUptime&#34;,&#34;tags&#34;:{&#34;driverPublicDns&#34;:&#34;ec2-54-200-33-194.us-west-2.compute.amazonaws.com&#34;,&#34;clusterEbsVolumeType&#34;:&#34;GENERAL_PURPOSE_SSD&#34;,&#34;instanceWorkerEnvId&#34;:&#34;default-worker-env&#34;,&#34;instanceBootstrapType&#34;:&#34;ssh&#34;,&#34;opType&#34;:&#34;TimerTask&#34;,&#34;containerZoneId&#34;:&#34;us-west-2c&#34;,&#34;clusterScalingType&#34;:&#34;fixed_size&#34;,&#34;clusterPinned&#34;:&#34;false&#34;,&#34;clusterNodeType&#34;:&#34;dev-tier-node&#34;,&#34;clusterSku&#34;:&#34;STANDARD_SKU&#34;,&#34;driverContainerId&#34;:&#34;935571070b2e44a2b6a778ea015199f2&#34;,&#34;ngrokNpipEnabled&#34;:&#34;false&#34;,&#34;clusterFirstOnDemand&#34;:&#34;0&#34;,&#34;clusterState&#34;:&#34;Pending&#34;,&#34;enableCredentialPassthrough&#34;:&#34;false&#34;,&#34;clusterLogDeliveryEnabled&#34;:&#34;false&#34;,&#34;clusterLogDestination&#34;:&#34;&#34;,&#34;isSingleUserCluster&#34;:&#34;false&#34;,&#34;driverNodeType&#34;:&#34;dev-tier-node&#34;,&#34;driverInstancePrivateIp&#34;:&#34;10.172.225.28&#34;,&#34;isIMv2Enabled&#34;:&#34;false&#34;,&#34;clusterTargetWorkers&#34;:&#34;0&#34;,&#34;numPerGlobalInitScriptsV2&#34;:&#34;0&#34;,&#34;databricksCommit&#34;:&#34;4ff930792a9bc9a222b7ff7dfb98341e704d047b&#34;,&#34;numPerClusterInitScriptsV2&#34;:&#34;0&#34;,&#34;enableJobsAutostart&#34;:&#34;true&#34;,&#34;clusterStateMessage&#34;:&#34;Starting Spark&#34;,&#34;apacheCommit&#34;:&#34;c9b62711fdec24160c4bdeff8fc09eedb0b75ee0&#34;,&#34;projectName&#34;:&#34;driver&#34;,&#34;region&#34;:&#34;us-west-2&#34;,&#34;userProvidedRemoteVolumeSizeGb&#34;:&#34;0&#34;,&#34;userProvidedRemoteVolumeCount&#34;:&#34;0&#34;,&#34;hostName&#34;:&#34;0212-091341-clan990-10-172-246-56&#34;,&#34;clusterEbsVolumeSize&#34;:&#34;0&#34;,&#34;enableJdbcAutoStart&#34;:&#34;true&#34;,&#34;driverInstanceId&#34;:&#34;i-00e89bf779718895a&#34;,&#34;clusterGeneration&#34;:&#34;0&#34;,&#34;autoTerminationMinutes&#34;:&#34;120&#34;,&#34;clusterId&#34;:&#34;0212-091341-clan990&#34;,&#34;clusterAvailability&#34;:&#34;ON_DEMAND&#34;,&#34;parentOpId&#34;:&#34;Thread-11&#34;,&#34;sparkVersion&#34;:&#34;7.5.x-scala2.12&#34;,&#34;hailEnabled&#34;:&#34;false&#34;,&#34;clusterOwnerOrgId&#34;:&#34;4188761774711191&#34;,&#34;workerEnvironmentId&#34;:&#34;default-worker-env&#34;,&#34;tier&#34;:&#34;tier-0&#34;,&#34;enableDfAcls&#34;:&#34;false&#34;,&#34;rootOpId&#34;:&#34;TimerTask-78a0b28696f27c88&#34;,&#34;clusterNoDriverDaemon&#34;:&#34;false&#34;,&#34;cloudProvider&#34;:&#34;AWS&#34;,&#34;clusterName&#34;:&#34;BDTT LabWork&#34;,&#34;clusterPythonVersion&#34;:&#34;3&#34;,&#34;clusterOwnerUserId&#34;:&#34;1878096729107785&#34;,&#34;privateLinkEnabled&#34;:&#34;false&#34;,&#34;clusterEbsVolumeCount&#34;:&#34;0&#34;,&#34;clusterCreator&#34;:&#34;Webapp&#34;,&#34;clusterAllTags&#34;:&#34;[{\&#34;key\&#34;:\&#34;Name\&#34;,\&#34;value\&#34;:\&#34;ce-worker\&#34;}]&#34;,&#34;enableLocalDiskEncryption&#34;:&#34;false&#34;,&#34;clusterSpotBidPricePercent&#34;:&#34;100&#34;,&#34;clusterResourceClass&#34;:&#34;default&#34;,&#34;enableSqlAclsOnly&#34;:&#34;false&#34;,&#34;buildHash&#34;:&#34;6ff40373028aaf75a88df9ee42bea90cb16e98d3&#34;,&#34;containerType&#34;:&#34;LXC&#34;,&#34;clusterNumSshKeys&#34;:&#34;0&#34;,&#34;opId&#34;:&#34;TimerTask-78a0b28696f27c88&#34;,&#34;branchName&#34;:&#34;branch-3.38-3776-d91a3e15&#34;,&#34;userProvidedRemoteVolumeType&#34;:&#34;ebs_volume_type: GENERAL_PURPOSE_SSD\n&#34;,&#34;opTarget&#34;:&#34;UptimeLogger:driver&#34;,&#34;driverContainerPrivateIp&#34;:&#34;10.172.246.56&#34;,&#34;enableElasticDisk&#34;:&#34;false&#34;,&#34;clusterMetastoreAccessType&#34;:&#34;RDS_DIRECT&#34;,&#34;dataPlaneRegion&#34;:&#34;us-west-2&#34;,&#34;instanceWorkerEnvNetworkType&#34;:&#34;default&#34;,&#34;clusterWorkers&#34;:&#34;0&#34;},&#34;timestamp&#34;:1613124005852,&#34;v&#34;:3,&#34;quantity&#34;:30000.0,&#34;blob&#34;:null}
#
# {&#34;metric&#34;:&#34;sparkNumPendingTasks&#34;,&#34;tags&#34;:{&#34;driverPublicDns&#34;:&#34;ec2-54-200-33-194.us-west-2.compute.amazonaws.com&#34;,&#34;clusterEbsVolumeType&#34;:&#34;GENERAL_PURPOSE_SSD&#34;,&#34;instanceWorkerEnvId&#34;:&#34;default-worker-env&#34;,&#34;instanceBootstrapType&#34;:&#34;ssh&#34;,&#34;opType&#34;:&#34;ServiceMain&#34;,&#34;containerZoneId&#34;:&#34;us-west-2c&#34;,&#34;clusterScalingType&#34;:&#34;fixed_size&#34;,&#34;clusterPinned&#34;:&#34;false&#34;,&#34;clusterNodeType&#34;:&#34;dev-tier-node&#34;,&#34;clusterSku&#34;:&#34;STANDARD_SKU&#34;,&#34;driverContainerId&#34;:&#34;935571070b2e44a2b6a778ea015199f2&#34;,&#34;ngrokNpipEnabled&#34;:&#34;false&#34;,&#34;clusterFirstOnDemand&#34;:&#34;0&#34;,&#34;clusterState&#34;:&#34;Pending&#34;,&#34;enableCredentialPassthrough&#34;:&#34;false&#34;,&#34;clusterLogDeliveryEnabled&#34;:&#34;false&#34;,&#34;clusterLogDestination&#34;:&#34;&#34;,&#34;isSingleUserCluster&#34;:&#34;false&#34;,&#34;driverNodeType&#34;:&#34;dev-tier-node&#34;,&#34;driverInstancePrivateIp&#34;:&#34;10.172.225.28&#34;,&#34;isIMv2Enabled&#34;:&#34;false&#34;,&#34;clusterTargetWorkers&#34;:&#34;0&#34;,&#34;numPerGlobalInitScriptsV2&#34;:&#34;0&#34;,&#34;databricksCommit&#34;:&#34;4ff930792a9bc9a222b7ff7dfb98341e704d047b&#34;,&#34;numPerClusterInitScriptsV2&#34;:&#34;0&#34;,&#34;enableJobsAutostart&#34;:&#34;true&#34;,&#34;clusterStateMessage&#34;:&#34;Starting Spark&#34;,&#34;apacheCommit&#34;:&#34;c9b62711fdec24160c4bdeff8fc09eedb0b75ee0&#34;,&#34;projectName&#34;:&#34;driver&#34;,&#34;region&#34;:&#34;us-west-2&#34;,&#34;userProvidedRemoteVolumeSizeGb&#34;:&#34;0&#34;,&#34;userProvidedRemoteVolumeCount&#34;:&#34;0&#34;,&#34;hostName&#34;:&#34;0212-091341-clan990-10-172-246-56&#34;,&#34;clusterEbsVolumeSize&#34;:&#34;0&#34;,&#34;enableJdbcAutoStart&#34;:&#34;true&#34;,&#34;driverInstanceId&#34;:&#34;i-00e89bf779718895a&#34;,&#34;clusterGeneration&#34;:&#34;0&#34;,&#34;autoTerminationMinutes&#34;:&#34;120&#34;,&#34;clusterId&#34;:&#34;0212-091341-clan990&#34;,&#34;clusterAvailability&#34;:&#34;ON_DEMAND&#34;,&#34;samplingIntervalMillis&#34;:&#34;15000&#34;,&#34;parentOpId&#34;:&#34;Thread-1&#34;,&#34;sparkVersion&#34;:&#34;7.5.x-scala2.12&#34;,&#34;hailEnabled&#34;:&#34;false&#34;,&#34;clusterOwnerOrgId&#34;:&#34;4188761774711191&#34;,&#34;workerEnvironmentId&#34;:&#34;default-worker-env&#34;,&#34;tier&#34;:&#34;tier-0&#34;,&#34;enableDfAcls&#34;:&#34;false&#34;,&#34;rootOpId&#34;:&#34;ServiceMain-78a0b28696f20002&#34;,&#34;clusterNoDriverDaemon&#34;:&#34;false&#34;,&#34;cloudProvider&#34;:&#34;AWS&#34;,&#34;clusterName&#34;:&#34;BDTT LabWork&#34;,&#34;clusterPythonVersion&#34;:&#34;3&#34;,&#34;clusterOwnerUserId&#34;:&#34;1878096729107785&#34;,&#34;privateLinkEnabled&#34;:&#34;false&#34;,&#34;clusterEbsVolumeCount&#34;:&#34;0&#34;,&#34;clusterCreator&#34;:&#34;Webapp&#34;,&#34;clusterAllTags&#34;:&#34;[{\&#34;key\&#34;:\&#34;Name\&#34;,\&#34;value\&#34;:\&#34;ce-worker\&#34;}]&#34;,&#34;enableLocalDiskEncryption&#34;:&#34;false&#34;,&#34;clusterSpotBidPricePercent&#34;:&#34;100&#34;,&#34;clusterResourceClass&#34;:&#34;default&#34;,&#34;enableSqlAclsOnly&#34;:&#34;false&#34;,&#34;buildHash&#34;:&#34;6ff40373028aaf75a88df9ee42bea90cb16e98d3&#34;,&#34;containerType&#34;:&#34;LXC&#34;,&#34;clusterNumSshKeys&#34;:&#34;0&#34;,&#34;opId&#34;:&#34;ServiceMain-78a0b28696f20002&#34;,&#34;branchName&#34;:&#34;branch-3.38-3776-d91a3e15&#34;,&#34;userProvidedRemoteVolumeType&#34;:&#34;ebs_volume_type: GENERAL_PURPOSE_SSD\n&#34;,&#34;opTarget&#34;:&#34;serviceSpecificMain&#34;,&#34;driverContainerPrivateIp&#34;:&#34;10.172.246.56&#34;,&#34;enableElasticDisk&#34;:&#34;false&#34;,&#34;clusterMetastoreAccessType&#34;:&#34;RDS_DIRECT&#34;,&#34;sparkApp

# %% [markdown]
# --> 7. To introduce a bit of reusability, you can declare a cell which defines a variable containing your file path first, and then
# modify the cell defined in point 6 to use the variable. You should therefore have one cell, preceding the cell you creted
# in Point 6, containing:
#
# filepath = "/databricks/driver/logs/usage.json"
#
# And the modified code should now contain:

# %%
filepath = "/databricks/driver/logs/usage.json"
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# and now --> 

fp = open ( filepath , "r")
for line in fp:
  print ( line )
fp. close ()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">{&#34;metric&#34;:&#34;serviceUptime&#34;,&#34;tags&#34;:{&#34;driverPublicDns&#34;:&#34;ec2-54-200-33-194.us-west-2.compute.amazonaws.com&#34;,&#34;clusterEbsVolumeType&#34;:&#34;GENERAL_PURPOSE_SSD&#34;,&#34;instanceWorkerEnvId&#34;:&#34;default-worker-env&#34;,&#34;instanceBootstrapType&#34;:&#34;ssh&#34;,&#34;opType&#34;:&#34;TimerTask&#34;,&#34;containerZoneId&#34;:&#34;us-west-2c&#34;,&#34;clusterScalingType&#34;:&#34;fixed_size&#34;,&#34;clusterPinned&#34;:&#34;false&#34;,&#34;clusterNodeType&#34;:&#34;dev-tier-node&#34;,&#34;clusterSku&#34;:&#34;STANDARD_SKU&#34;,&#34;driverContainerId&#34;:&#34;935571070b2e44a2b6a778ea015199f2&#34;,&#34;ngrokNpipEnabled&#34;:&#34;false&#34;,&#34;clusterFirstOnDemand&#34;:&#34;0&#34;,&#34;clusterState&#34;:&#34;Pending&#34;,&#34;enableCredentialPassthrough&#34;:&#34;false&#34;,&#34;clusterLogDeliveryEnabled&#34;:&#34;false&#34;,&#34;clusterLogDestination&#34;:&#34;&#34;,&#34;isSingleUserCluster&#34;:&#34;false&#34;,&#34;driverNodeType&#34;:&#34;dev-tier-node&#34;,&#34;driverInstancePrivateIp&#34;:&#34;10.172.225.28&#34;,&#34;isIMv2Enabled&#34;:&#34;false&#34;,&#34;clusterTargetWorkers&#34;:&#34;0&#34;,&#34;numPerGlobalInitScriptsV2&#34;:&#34;0&#34;,&#34;databricksCommit&#34;:&#34;4ff930792a9bc9a222b7ff7dfb98341e704d047b&#34;,&#34;numPerClusterInitScriptsV2&#34;:&#34;0&#34;,&#34;enableJobsAutostart&#34;:&#34;true&#34;,&#34;clusterStateMessage&#34;:&#34;Starting Spark&#34;,&#34;apacheCommit&#34;:&#34;c9b62711fdec24160c4bdeff8fc09eedb0b75ee0&#34;,&#34;projectName&#34;:&#34;driver&#34;,&#34;region&#34;:&#34;us-west-2&#34;,&#34;userProvidedRemoteVolumeSizeGb&#34;:&#34;0&#34;,&#34;userProvidedRemoteVolumeCount&#34;:&#34;0&#34;,&#34;hostName&#34;:&#34;0212-091341-clan990-10-172-246-56&#34;,&#34;clusterEbsVolumeSize&#34;:&#34;0&#34;,&#34;enableJdbcAutoStart&#34;:&#34;true&#34;,&#34;driverInstanceId&#34;:&#34;i-00e89bf779718895a&#34;,&#34;clusterGeneration&#34;:&#34;0&#34;,&#34;autoTerminationMinutes&#34;:&#34;120&#34;,&#34;clusterId&#34;:&#34;0212-091341-clan990&#34;,&#34;clusterAvailability&#34;:&#34;ON_DEMAND&#34;,&#34;parentOpId&#34;:&#34;Thread-11&#34;,&#34;sparkVersion&#34;:&#34;7.5.x-scala2.12&#34;,&#34;hailEnabled&#34;:&#34;false&#34;,&#34;clusterOwnerOrgId&#34;:&#34;4188761774711191&#34;,&#34;workerEnvironmentId&#34;:&#34;default-worker-env&#34;,&#34;tier&#34;:&#34;tier-0&#34;,&#34;enableDfAcls&#34;:&#34;false&#34;,&#34;rootOpId&#34;:&#34;TimerTask-78a0b28696f27c88&#34;,&#34;clusterNoDriverDaemon&#34;:&#34;false&#34;,&#34;cloudProvider&#34;:&#34;AWS&#34;,&#34;clusterName&#34;:&#34;BDTT LabWork&#34;,&#34;clusterPythonVersion&#34;:&#34;3&#34;,&#34;clusterOwnerUserId&#34;:&#34;1878096729107785&#34;,&#34;privateLinkEnabled&#34;:&#34;false&#34;,&#34;clusterEbsVolumeCount&#34;:&#34;0&#34;,&#34;clusterCreator&#34;:&#34;Webapp&#34;,&#34;clusterAllTags&#34;:&#34;[{\&#34;key\&#34;:\&#34;Name\&#34;,\&#34;value\&#34;:\&#34;ce-worker\&#34;}]&#34;,&#34;enableLocalDiskEncryption&#34;:&#34;false&#34;,&#34;clusterSpotBidPricePercent&#34;:&#34;100&#34;,&#34;clusterResourceClass&#34;:&#34;default&#34;,&#34;enableSqlAclsOnly&#34;:&#34;false&#34;,&#34;buildHash&#34;:&#34;6ff40373028aaf75a88df9ee42bea90cb16e98d3&#34;,&#34;containerType&#34;:&#34;LXC&#34;,&#34;clusterNumSshKeys&#34;:&#34;0&#34;,&#34;opId&#34;:&#34;TimerTask-78a0b28696f27c88&#34;,&#34;branchName&#34;:&#34;branch-3.38-3776-d91a3e15&#34;,&#34;userProvidedRemoteVolumeType&#34;:&#34;ebs_volume_type: GENERAL_PURPOSE_SSD\n&#34;,&#34;opTarget&#34;:&#34;UptimeLogger:driver&#34;,&#34;driverContainerPrivateIp&#34;:&#34;10.172.246.56&#34;,&#34;enableElasticDisk&#34;:&#34;false&#34;,&#34;clusterMetastoreAccessType&#34;:&#34;RDS_DIRECT&#34;,&#34;dataPlaneRegion&#34;:&#34;us-west-2&#34;,&#34;instanceWorkerEnvNetworkType&#34;:&#34;default&#34;,&#34;clusterWorkers&#34;:&#34;0&#34;},&#34;timestamp&#34;:1613124005852,&#34;v&#34;:3,&#34;quantity&#34;:30000.0,&#34;blob&#34;:null}
#
# {&#34;metric&#34;:&#34;sparkNumPendingTasks&#34;,&#34;tags&#34;:{&#34;driverPublicDns&#34;:&#34;ec2-54-200-33-194.us-west-2.compute.amazonaws.com&#34;,&#34;clusterEbsVolumeType&#34;:&#34;GENERAL_PURPOSE_SSD&#34;,&#34;instanceWorkerEnvId&#34;:&#34;default-worker-env&#34;,&#34;instanceBootstrapType&#34;:&#34;ssh&#34;,&#34;opType&#34;:&#34;ServiceMain&#34;,&#34;containerZoneId&#34;:&#34;us-west-2c&#34;,&#34;clusterScalingType&#34;:&#34;fixed_size&#34;,&#34;clusterPinned&#34;:&#34;false&#34;,&#34;clusterNodeType&#34;:&#34;dev-tier-node&#34;,&#34;clusterSku&#34;:&#34;STANDARD_SKU&#34;,&#34;driverContainerId&#34;:&#34;935571070b2e44a2b6a778ea015199f2&#34;,&#34;ngrokNpipEnabled&#34;:&#34;false&#34;,&#34;clusterFirstOnDemand&#34;:&#34;0&#34;,&#34;clusterState&#34;:&#34;Pending&#34;,&#34;enableCredentialPassthrough&#34;:&#34;false&#34;,&#34;clusterLogDeliveryEnabled&#34;:&#34;false&#34;,&#34;clusterLogDestination&#34;:&#34;&#34;,&#34;isSingleUserCluster&#34;:&#34;false&#34;,&#34;driverNodeType&#34;:&#34;dev-tier-node&#34;,&#34;driverInstancePrivateIp&#34;:&#34;10.172.225.28&#34;,&#34;isIMv2Enabled&#34;:&#34;false&#34;,&#34;clusterTargetWorkers&#34;:&#34;0&#34;,&#34;numPerGlobalInitScriptsV2&#34;:&#34;0&#34;,&#34;databricksCommit&#34;:&#34;4ff930792a9bc9a222b7ff7dfb98341e704d047b&#34;,&#34;numPerClusterInitScriptsV2&#34;:&#34;0&#34;,&#34;enableJobsAutostart&#34;:&#34;true&#34;,&#34;clusterStateMessage&#34;:&#34;Starting Spark&#34;,&#34;apacheCommit&#34;:&#34;c9b62711fdec24160c4bdeff8fc09eedb0b75ee0&#34;,&#34;projectName&#34;:&#34;driver&#34;,&#34;region&#34;:&#34;us-west-2&#34;,&#34;userProvidedRemoteVolumeSizeGb&#34;:&#34;0&#34;,&#34;userProvidedRemoteVolumeCount&#34;:&#34;0&#34;,&#34;hostName&#34;:&#34;0212-091341-clan990-10-172-246-56&#34;,&#34;clusterEbsVolumeSize&#34;:&#34;0&#34;,&#34;enableJdbcAutoStart&#34;:&#34;true&#34;,&#34;driverInstanceId&#34;:&#34;i-00e89bf779718895a&#34;,&#34;clusterGeneration&#34;:&#34;0&#34;,&#34;autoTerminationMinutes&#34;:&#34;120&#34;,&#34;clusterId&#34;:&#34;0212-091341-clan990&#34;,&#34;clusterAvailability&#34;:&#34;ON_DEMAND&#34;,&#34;samplingIntervalMillis&#34;:&#34;15000&#34;,&#34;parentOpId&#34;:&#34;Thread-1&#34;,&#34;sparkVersion&#34;:&#34;7.5.x-scala2.12&#34;,&#34;hailEnabled&#34;:&#34;false&#34;,&#34;clusterOwnerOrgId&#34;:&#34;4188761774711191&#34;,&#34;workerEnvironmentId&#34;:&#34;default-worker-env&#34;,&#34;tier&#34;:&#34;tier-0&#34;,&#34;enableDfAcls&#34;:&#34;false&#34;,&#34;rootOpId&#34;:&#34;ServiceMain-78a0b28696f20002&#34;,&#34;clusterNoDriverDaemon&#34;:&#34;false&#34;,&#34;cloudProvider&#34;:&#34;AWS&#34;,&#34;clusterName&#34;:&#34;BDTT LabWork&#34;,&#34;clusterPythonVersion&#34;:&#34;3&#34;,&#34;clusterOwnerUserId&#34;:&#34;1878096729107785&#34;,&#34;privateLinkEnabled&#34;:&#34;false&#34;,&#34;clusterEbsVolumeCount&#34;:&#34;0&#34;,&#34;clusterCreator&#34;:&#34;Webapp&#34;,&#34;clusterAllTags&#34;:&#34;[{\&#34;key\&#34;:\&#34;Name\&#34;,\&#34;value\&#34;:\&#34;ce-worker\&#34;}]&#34;,&#34;enableLocalDiskEncryption&#34;:&#34;false&#34;,&#34;clusterSpotBidPricePercent&#34;:&#34;100&#34;,&#34;clusterResourceClass&#34;:&#34;default&#34;,&#34;enableSqlAclsOnly&#34;:&#34;false&#34;,&#34;buildHash&#34;:&#34;6ff40373028aaf75a88df9ee42bea90cb16e98d3&#34;,&#34;containerType&#34;:&#34;LXC&#34;,&#34;clusterNumSshKeys&#34;:&#34;0&#34;,&#34;opId&#34;:&#34;ServiceMain-78a0b28696f20002&#34;,&#34;branchName&#34;:&#34;branch-3.38-3776-d91a3e15&#34;,&#34;userProvidedRemoteVolumeType&#34;:&#34;ebs_volume_type: GENERAL_PURPOSE_SSD\n&#34;,&#34;opTarget&#34;:&#34;serviceSpecificMain&#34;,&#34;driverContainerPrivateIp&#34;:&#34;10.172.246.56&#34;,&#34;enableElasticDisk&#34;:&#34;false&#34;,&#34;clusterMetastoreAccessType&#34;:&#34;RDS_DIRECT&#34;,&#34;sparkApp

# %% [markdown]
# --> 8. To demonstrate the reusability, copy the sample logs/part-00000 file from DBFS to your local file space (so you can
# run your local data based function):

# %%
dbutils.fs.cp("/databricks-datasets/sample_logs/part-00000", "file:/tmp/sample_log.txt")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[15]: True</div>

# %% [markdown]
# --> 9. Now change the filepath variable to correspond to "/tmp/sample log.txt" and run the print lines cell again. Did the
# output change?

# %%
filepath = "/tmp/sample_log.txt"

fp = open ( filepath , "r")
for line in fp:
  print ( line )
fp. close ()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">3.3.3.3 - user1 [21/Jun/2014:10:00:00 -0700] &#34;GET /endpoint_27 HTTP/1.1&#34; 200 21
#
# 4.4.4.4 - user2 [21/Feb/2014:10:00:00 -0300] &#34;GET /endpoint_988 HTTP/1.1&#34; 200 435
#
# 3.3.3.3 - user2 [21/Jan/2014:10:00:00 -0200] &#34;GET /endpoint_271 HTTP/1.1&#34; 200 11
#
# 4.4.4.4 - user1 [21/Mar/2014:10:00:00 -0400] &#34;POST /endpoint_906 HTTP/1.1&#34; 401 182
#
# 3.3.3.3 - - [21/May/2014:10:00:00 -0600] &#34;GET /endpoint_381 HTTP/1.1&#34; 500 208
#
# 2.2.2.2 - - [21/May/2014:10:00:00 -0600] &#34;GET /endpoint_99 HTTP/1.1&#34; 500 201
#
# 3.3.3.3 - user1 [21/Jul/2014:10:00:00 -0800] &#34;GET /endpoint_185 HTTP/1.1&#34; 200 377
#
# 4.4.4.4 - - [21/Mar/2014:10:00:00 -0400] &#34;PUT /endpoint_339 HTTP/1.1&#34; 200 428
#
# 3.3.3.3 - - [21/Apr/2014:10:00:00 -0500] &#34;PUT /endpoint_711 HTTP/1.1&#34; 200 316
#
# 2.2.2.2 - - [21/Apr/2014:10:00:00 -0500] &#34;POST /endpoint_791 HTTP/1.1&#34; 200 374
#
# 127.0.0.1 - - [21/Jul/2014:10:00:00 -0800] &#34;GET /endpoint_137 HTTP/1.1&#34; 500 159
#
# 4.4.4.4 - user1 [21/Jan/2014:10:00:00 -0200] &#34;POST /endpoint_718 HTTP/1.1&#34; 200 291
#
# 3.3.3.3 - - [21/Mar/2014:10:00:00 -0400] &#34;GET /endpoint_438 HTTP/1.1&#34; 500 467
#
# 2.2.2.2 - - [21/Feb/2014:10:00:00 -0300] &#34;POST /endpoint_140 HTTP/1.1&#34; 200 287
#
# 1.1.1.1 - user2 [21/Jan/2014:10:00:00 -0200] &#34;GET /endpoint_75 HTTP/1.1&#34; 200 92
#
# 1.1.1.1 - - [21/Apr/2014:10:00:00 -0500] &#34;PUT /endpoint_980 HTTP/1.1&#34; 500 39
#
# 127.0.0.1 - - [21/May/2014:10:00:00 -0600] &#34;GET /endpoint_705 HTTP/1.1&#34; 200 155
#
# 1.1.1.1 - user2 [21/Jul/2014:10:00:00 -0800] &#34;GET /endpoint_637 HTTP/1.1&#34; 200 461
#
# 3.3.3.3 - - [21/Jul/2014:10:00:00 -0800] &#34;GET /endpoint_232 HTTP/1.1&#34; 200 240
#
# 3.3.3.3 - - [21/Jun/2014:10:00:00 -0700] &#34;GET /endpoint_927 HTTP/1.1&#34; 200 370
#
# 1.1.1.1 - - [21/Jan/2014:10:00:00 -0200] &#34;GET /endpoint_508 HTTP/1.1&#34; 500 180
#
# 2.2.2.2 - - [21/Apr/2014:10:00:00 -0500] &#34;GET /endpoint_355 HTTP/1.1&#34; 200 494
#
# 3.3.3.3 - - [21/May/2014:10:00:00 -0600] &#34;POST /endpoint_394 HTTP/1.1&#34; 500 164
#
# 1.1.1.1 - - [21/Apr/2014:10:00:00 -0500] &#34;GET /endpoint_431 HTTP/1.1&#34; 200 223
#
# 1.1.1.1 - - [21/May/2014:10:00:00 -0600] &#34;PUT /endpoint_316 HTTP/1.1&#34; 200 47
#
# 1.1.1.1 - - [21/Apr/2014:10:00:00 -0500] &#34;GET /endpoint_238 HTTP/1.1&#34; 200 246
#
# 4.4.4.4 - user1 [21/Mar/2014:10:00:00 -0400] &#34;POST /endpoint_61 HTTP/1.1&#34; 200 149
#
# 127.0.0.1 - user1 [21/Mar/2014:10:00:00 -0400] &#34;POST /endpoint_452 HTTP/1.1&#34; 200 149
#
# 3.3.3.3 - user2 [21/May/2014:10:00:00 -0600] &#34;PUT /endpoint_579 HTTP/1.1&#34; 500 220
#
# 2.2.2.2 - user2 [21/Jun/2014:10:00:00 -0700] &#34;GET /endpoint_382 HTTP/1.1&#34; 500 311
#
# 2.2.2.2 - - [21/Apr/2014:10:00:00 -0500] &#34;GET /endpoint_275 HTTP/1.1&#34; 200 412
#
# 4.4.4.4 - user1 [21/Jan/2014:10:00:00 -0200] &#34;GET /endpoint_607 HTTP/1.1&#34; 500 411
#
# 3.3.3.3 - - [21/Apr/2014:10:00:00 -0500] &#34;GET /endpoint_390 HTTP/1.1&#34; 200 498
#
# 4.4.4.4 - - [21/Apr/2014:10:00:00 -0500] &#34;GET /endpoint_421 HTTP/1.1&#34; 200 434
#
# 127.0.0.1 - user2 [21/Mar/2014:10:00:00 -0400] &#34;GET /endpoint_753 HTTP/1.1&#34; 200 175
#
# 4.4.4.4 - user1 [21/Jan/2014:10:00:00 -0200] &#34;POST /endpoint_755 HTTP/1.1&#34; 200 361
#
# 2.2.2.2 - - [21/Jun/2014:10:00:00 -0700] &#34;POST /endpoint_180 HTTP/1.1&#34; 200 358
#
# 4.4.4.4 - - [21/Feb/2014:10:00:00 -0300] &#34;GET /endpoint_399 HTTP/1.1&#34; 200 222
#
# 4.4.4.4 - user2 [21/May/2014:10:00:00 -0600] &#34;GET /endpoint_108 HTTP/1.1&#34; 200 356
#
# 1.1.1.1 - - [21/Mar/2014:10:00:00 -0400] &#34;GET /endpoint_374 HTTP/1.1&#34; 200 65
#
# 4.4.4.4 - user1 [21/May/2014:10:00:00 -0600] &#34;GET /endpoint_96 HTTP/1.1&#34; 200 376
#
# 3.3.3.3 - - [21/Jul/2014:10:00:00 -0800] &#34;GET /endpoint_820 HTTP/1.1&#34; 200 270
#
# 3.3.3.3 - - [21/Jun/2014:10:00:00 -0700] &#34;GET /endpoint_961 HTTP/1.1&#34; 200 447
#
# 1.1.1.1 - - [21/May/2014:10:00:00 -0600] &#34;GET /endpoint_498 HTTP/1.1&#34; 200 404
#
# 127.0.0.1 - - [21/Jun/2014:10:00:00 -0700] &#34;GET /endpoint_863 HTTP/1.1&#34; 401 99
#
# 127.0.0.1 - - [21/Feb/2014:10:00:00 -0300] &#34;GET /endpoint_804 HTTP/1.1&#34; 200 438
#
# 4.4.4.4 - user1 [21/Mar/2014:10:00:00 -0400] &#34;PUT /endpoint_432 HTTP/1.1&#34; 200 184
#
# 2.2.2.2 - - [21/Jan/2014:10:00:00 -0200] &#34;POST /endpoint_832 HTTP/1.1&#34; 200 338
#
# 127.0.0.1 - - [21/Feb/2014:10:00:00 -0300] &#34;GET /endpoint_790 HTTP/1.1&#34; 401 118
#
# 4.4.4.4 - - [21/Jan/2014:10:00:00 -0200] &#34;GET /endpoint_507 HTTP/1.1&#34; 401 465
#
# 127.0.0.1 - - [21/Jun/2014:10:00:00 -0700] &#34;GET /endpoint_871 HTTP/1.1&#34; 401 421
#
# 4.4.4.4 - - [21/Jul/2014:10:00:00 -0800] &#34;GET /endpoint_825 HTTP/1.1&#34; 500 189
#
# 2.2.2.2 - - [21/Apr/2014:10:00:00 -0500] &#34;GET /endpoint_766 HTTP/1.1&#34; 200 132
#
# 3.3.3.3 - user1 [21/May/2014:10:00:00 -0600] &#34;GET /endpoint_752 HTTP/1.1&#34; 500 287
#
# 3.3.3.3 - - [21/Jul/2014:10:00:00 -0800] &#34;POST /endpoint_488 HTTP/1.1&#34; 200 426
#
# 4.4.4.4 - user1 [21/Apr/2014:10:00:00 -0500] &#34;GET /endpoint_252 HTTP/1.1&#34; 200 38
#
# 2.2.2.2 - - [21/Apr/2014:10:00:00 -0500] &#34;POST /endpoint_858 HTTP/1.1&#34; 401 310
#
# 2.2.2.2 - - [21/May/2014:10:00:00 -0600] &#34;GET /endpoint_757 HTTP/1.1&#34; 401 282
#
# 4.4.4.4 - user2 [21/Apr/2014:10:00:00 -0500] &#34;GET /endpoint_854 HTTP/1.1&#34; 200 479
#
# 127.0.0.1 - - [21/Jul/2014:10:00:00 -0800] &#34;POST /endpoint_561 HTTP/1.1&#34; 200 153
#
# 127.0.0.1 - - [21/Jan/2014:10:00:00 -0200] &#34;GET /endpoint_78 HTTP/1.1&#34; 401 2
#
# 2.2.2.2 - user1 [21/Jul/2014:10:00:00 -0800] &#34;GET /endpoint_946 HTTP/1.1&#34; 200 173
#
# 1.1.1.1 - user1 [21/Apr/2014:10:00:00 -0500] &#34;GET /endpoint_638 HTTP/1.1&#34; 200 413
#
# 2.2.2.2 - - [21/Apr/2014:10:00:00 -0500] &#34;POST /endpoint_666 HTTP/1.1&#34; 200 27
#
# 4.4.4.4 - user2 [21/Feb/2014:10:00:00 -0300] &#34;GET /endpoint_628 HTTP/1.1&#34; 200 7
#
# 3.3.3.3 - user1 [21/May/2014:10:00:00 -0600] &#34;POST /endpoint_346 HTTP/1.1&#34; 200 414
#
# 4.4.4.4 - - [21/Jan/2014:10:00:00 -0200] &#34;GET /endpoint_980 HTTP/1.1&#34; 200 490
#
# 4.4.4.4 - user2 [21/Feb/2014:10:00:00 -0300] &#34;PUT /endpoint_473 HTTP/1.1&#34; 200 245
#
# 2.2.2.2 - - [21/Jun/2014:10:00:00 -0700] &#34;GET /endpoint_98 HTTP/1.1&#34; 200 321
#
# 127.0.0.1 - user1 [21/May/2014:10:00:00 -0600] &#34;PUT /endpoint_582 HTTP/1.1&#34; 200 157
#
# 1.1.1.1 - user2 [21/Feb/2014:10:00:00 -0300] &#34;PUT /endpoint_299 HTTP/1.1&#34; 401 176
#
# 1.1.1.1 - - [21/Feb/2014:10:00:00 -0300] &#34;GET /endpoint_874 HTTP/1.1&#34; 200 360
#
# 4.4.4.4 - - [21/Apr/2014:10:00:00 -0500] &#34;GET /endpoint_178 HTTP/1.1&#34; 200 30
#
# 127.0.0.1 - user2 [21/Jan/2014:10:00:00 -0200] &#34;GET /endpoint_51 HTTP/1.1&#34; 200 373
#
# 3.3.3.3 - user1 [21/Jun/2014:10:00:00 -0700] &#34;POST /endpoint_96 HTTP/1.1&#34; 200 196
#
# 3.3.3.3 - user2 [21/Mar/2014:10:00:00 -0400] &#34;GET /endpoint_435 HTTP/1.1&#34; 200 250
#
# 1.1.1.1 - user2 [21/Jun/2014:10:00:00 -0700] &#34;GET /endpoint_428 HTTP/1.1&#34; 401 117
#
# 127.0.0.1 - - [21/Feb/2014:10:00:00 -0300] &#34;GET /endpoint_584 HTTP/1.1&#34; 401 87
#
# 127.0.0.1 - user2 [21/Jun/2014:10:00:00 -0700] &#34;GET /endpoint_697 HTTP/1.1&#34; 200 325
#
# 2.2.2.2 - - [21/Jul/2014:10:00:00 -0800] &#34;GET /endpoint_423 HTTP/1.1&#34; 200 106
#
# 3.3.3.3 - - [21/Mar/2014:10:00:00 -0400] &#34;GET /endpoint_495 HTTP/1.1&#34; 200 95
#
# 3.3.3.3 - - [21/Mar/2014:10:00:00 -0400] &#34;GET /endpoint_997 HTTP/1.1&#34; 500 118
#
# 3.3.3.3 - user1 [21/Apr/2014:10:00:00 -0500] &#34;GET /endpoint_304 HTTP/1.1&#34; 200 439
#
# 1.1.1.1 - - [21/May/2014:10:00:00 -0600] &#34;GET /endpoint_153 HTTP/1.1&#34; 200 308
#
# 127.0.0.1 - - [21/Jun/2014:10:00:00 -0700] &#34;PUT /endpoint_637 HTTP/1.1&#34; 200 291
#
# 2.2.2.2 - - [21/Jun/2014:10:00:00 -0700] &#34;GET /endpoint_855 HTTP/1.1&#34; 200 436
#
# 3.3.3.3 - - [21/Jul/2014:10:00:00

# %% [markdown]
# --> 10. Python can count the lines in the file using a counter variable. Add another cell which does this - it is a slightly
# modified version of the previous pass through the file:

# %%
fp = open(filepath, "r")
count = 0

for line in fp:
  count += 1
  
fp.close()
print("Number of lines: ", count)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Number of lines:  3072
# </div>

# %% [markdown]
# Changing the value of the filepath variable and running both the cells which pass through the file will now run them
# both on the changed file!
#
# --> 11. (Optional) Is the number you found the same if you use the wc shell command? (Hint: it may not be - why do you
# think this is? )   --> answer - because the file path changes

# %%
# %sh 
echo "Number of lines: " 
cat "/tmp/sample_log.txt" | wc -l
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Number of lines:
# 3072
# </div>

# %% [markdown]
# ## Using functions for code reuse
#
# Another option for reusing the same bit of code is to define a function, which is passed the path to a file and prints the
# number of lines in that file.

# %% [markdown]
# --> 12. Insert the following function definition in a new cell. Note that executing this cell doesn't produce any output.

# %%
def print_num_lines_in_file(filename):
  fp = open (filename,"r")

  counter = 0

  for line in fp:
    counter += 1
    
  print ("Number of lines in", filename , "is", counter )
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# --> 13. You need to invoke the function that you have defined. Try it on the file you've already explored:

# %%
filepath = "/tmp/sample_log.txt"
print_num_lines_in_file(filepath)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Number of lines in /tmp/sample_log.txt is 3072
# </div>

# %%
filepath2 = "/databricks/driver/logs/usage.json"
print_num_lines_in_file(filepath2)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Number of lines in /databricks/driver/logs/usage.json is 34
# </div>

# %% [markdown]
# --> 14. (Optional) Can you create a new function which takes a file path and prints the number of words (separated by
# whitespace) on the first line of the file? (Hint: an option would be to use readline, split and len functions). You
# should run this function on /tmp/sample log.txt.

# %%
def first_line_words(filename):
  fp = open(filename, "r")
  read_text = fp.readline()

  print(read_text)
  print(read_text.split(" "))
  print("\nNumber of values in this line : ", len(read_text.split(" ")))


filepath = "/tmp/sample_log.txt"
first_line_words(filepath)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">3.3.3.3 - user1 [21/Jun/2014:10:00:00 -0700] &#34;GET /endpoint_27 HTTP/1.1&#34; 200 21
#
# [&#39;3.3.3.3&#39;, &#39;-&#39;, &#39;user1&#39;, &#39;[21/Jun/2014:10:00:00&#39;, &#39;-0700]&#39;, &#39;&#34;GET&#39;, &#39;/endpoint_27&#39;, &#39;HTTP/1.1&#34;&#39;, &#39;200&#39;, &#39;21\n&#39;]
#
# Number of values in this line :  10
# </div>
